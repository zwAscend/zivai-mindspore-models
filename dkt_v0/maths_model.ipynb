# %% [markdown]
# # DKT Training (MindSpore)
#
# This project now trains from the CLI using `train.py`.
#
# **Example:**
# ```bash
# python /workspace/dkt/train.py --data_path /workspace/dkt/assistments_2009_2010.csv --epochs 10 --batch_size 64
# ```

# %%
# This notebook is intentionally minimal.
print("Use train.py for GPU training with MindSpore.")
